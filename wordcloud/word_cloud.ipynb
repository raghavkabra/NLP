# 3105      2014-02-28T21:40:25Z
# 3106      2012-12-21T19:11:37Z
#
#                                                headline
# 0     Show HN: Checkout 'Containerize the Web' Site ...
# 1        Coghead Grinds To A Halt Heads To The Deadpool
# 3     Today's $60 1TB drive would have cost $1 trill...
# 4              How I Became Selfish and Changed My LIFE
# 5                         I Can't Wait for NoSQL to Die
# 6     Amazon Web Services Is Going On A Sales Hiring...
# 7     After 2 Years of Testing Venmo Opens Payment S...
# 8                       IDV User Experience: CraigsZips
# 9     Steve Jobs Preparing for First TV Appearance (...
# 10    Search Engine That Finds Internet-Connected Ca...
# 11    The rise of the mobile app user over the websi...
# 12                      Pep talk for new Ph.D. students
# 13    Consejos para elegir las cortinas para las ven...
# 14    unich's Move from Windows to Linux and Open So...
# 15    Put your work down play this game say "I Love ...
# 16    Purple Rain in the Saharan Desert: The First-e...
# 17          E-nose Startup – IoT for Your Home and Work
# 18                New insights into vaccination for HIV
# 19            You know owning a business is work right?
# 20    Sammy Screamer: A cute little movement sensor ...
# 21          The Hail Mary Cloud And The Lessons Learned
# 22                            14 Mays Gnlk Bur Yorumlar
# 23                          How to Become a Billionaire
# 24    Encryption Companies Throwing Shade Keeps Ever...
# 25    Can you patent a hyperlink? Patent trolls sure...
# 26                          Python 3: threat or menace?
# 27    Ionic-powered nanosatellite can go to the Moon...
# 28    Upwest Labs Launched the Y Combinator for Isra...
# 29                  Http://Facebook.com Is Down - Nice.
# 30          Google's Lost Social Network: Google Reader
# ...                                                 ...
# 3075      Watch Cowboy and Aliens Megavideo Online Free
# 3076  Show HN: podcastrobot - Convert any blog into ...
# 3077  Can you provide humanitarian aid without facil...
# 3079                       Google: How much is too big?
# 3080  agic and the Brain: Teller Reveals the Neurosc...
# 3081  SpeakingPal Plus Mobile Service for Learning E...
# 3082   Great Welcome Email examples from across the web
# 3083  Bill Gates Part of $12 Million Round for Satel...
# 3084                                5.7 GHz...or is it?
# 3085  How to build web apps and services in Go (Goph...
# 3086                  How not to interview Pythonistas.
# 3087            Use math for Valentine's Day happiness.
# 3088  Do behavioral analytics prevent brands from bu...
# 3090    Google Dart to "ultimately..replace JavaScript"
# 3091  Scientists Led By Makers of M&Ms Sequence the ...
# 3092  Voyager 1 finds edge of Solar System quite dif...
# 3093  Property Advisory And Certified Practising Val...
# 3094  Unintended Acceleration and Other Embedded Sof...
# 3095  This is how Apples top secret product developm...
# 3096  Google Donates $6.8 Million to San Francisco L...
# 3097                        True religion Outlet Online
# 3098              Tiny Hardware Firewall and VPN Client
# 3099     A framework for real-time mobile presentations
# 3100                           CRUD: Neo4j Define "Any"
# 3101                                               2013
# 3102  10 Product Management Hacks for Times when you...
# 3103  How a big movie studio (unfairly) forced a stu...
# 3104  Pebble Time Smartwatch Hits $1.53M in Kickstar...
# 3105                    Rapidly visualizing health data
# 3106      Assange's Xmas address from his embassy exile
#
# [2923 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# join tweets to a single string
words = ' '.join(tm['headline'])

# %%
#words

# %%
# remove URLs, RTs, and twitter handles
no_urls_no_tags = " ".join([word for word in words.split()
                            if 'http' not in word
                                and not word.startswith('@')
                                and word != 'RT'
                            ])

# %%
wordcloud = WordCloud(
                      
                      stopwords=STOPWORDS,
                      background_color='black',
                      width=1800,
                      height=1400
                     )

# %%
wordcloud.generate(no_urls_no_tags)

# %%
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('./my_twitter_wordcloud_1.png', dpi=300)
plt.show()
